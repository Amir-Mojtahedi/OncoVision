# %%
import pandas as pd

# %%
df = pd.read_csv('../dataset/breast-cancer.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df[["diagnosis", "concave_points_worst", "perimeter_worst", "concave_points_mean",
    "radius_worst", "perimeter_mean"]].sample(20)
# Out:
#     diagnosis  concave_points_worst  perimeter_worst  concave_points_mean  \
# 76          B               0.07407            91.36             0.065560
# 205         M               0.12520           117.70             0.040790
# 508         B               0.13570           109.80             0.045630
# 488         B               0.09815            86.57             0.031320
# 125         B               0.05104           100.30             0.011410
# 275         B               0.08946            79.46             0.074040
# 356         B               0.12580            94.22             0.056030
# 32          M               0.18470           136.10             0.120300
# 421         B               0.11080           114.10             0.063000
# 44          M               0.16070           105.50             0.052520
# 122         M               0.22480           180.90             0.201200
# 335         M               0.18270           143.20             0.099340
# ...
